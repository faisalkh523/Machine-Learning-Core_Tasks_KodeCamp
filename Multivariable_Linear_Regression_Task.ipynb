# %% [markdown]
# <a href="https://colab.research.google.com/github/faisalkh523/Machine-Learning-Core_Tasks_KodeCamp/blob/main/Multivariable_Linear_Regression_Task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub as kh
import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd

# %%
# !pip install kagglehub

# %%
path = kh.dataset_download("hussainnasirkhan/multiple-linear-regression-dataset")
print(path)

folder = path
files = os.listdir(folder)
files
# Out:
# ...
# 100%|██████████| 367/367 [00:00<00:00, 557kB/s]
# Extracting files...
# /root/.cache/kagglehub/datasets/hussainnasirkhan/multiple-linear-regression-dataset/versions/1
# ['multiple_linear_regression_dataset.csv']

# %%
df = pd.read_csv("/kaggle/input/multiple-linear-regression-dataset/multiple_linear_regression_dataset.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1485694484.py in <cell line: 0>()
# ----> 1 df = pd.read_csv("/kaggle/input/multiple-linear-regression-dataset/multiple_linear_regression_dataset.csv")
#       2 df.head()
#
# ...

# %%
print(df.shape)
df.isnull().sum()  # Check for missing values

df = df.dropna()  # Remove rows where any column is NaN

# %%
import numpy as np

# Assuming the CSV has columns named 'x1', 'x2', 'y'
X1 = df['age'].values
X2 = df['experience'].values
Y = df['income'].values

# %% [markdown]
# A FUNCTION FOR THE PREDICTION

# %%
def y_pred(X1, X2,  m1, m2, c):
  return m1 * X1 + m2 * X2 + c

# %% [markdown]
# FUNCTION TO COMPUTE COST FUNCTION

# %%
def mse(Y, y_pred):
  return np.mean((Y - y_pred)**2)

# %% [markdown]
# INITIALIZING THE PARAMETERS

# %%
m1, m2, c = 0, 0, 0
LR = 0.0001  # learning rate
epochs = 100_000
costs = []

# %% [markdown]
# COMPUTING THE GRADIENT AND UPDATING PARAMETERS

# %%
for i in range(epochs):
  Y_pred = y_pred(X1, X2, m1, m2, c)
  cost = mse(Y, Y_pred)
  costs.append(cost)
  print(f"epoch {i+1}: MSE = {cost}")     #Print out the MSE after each cycle of training.


  # computing the gradients
  dm1 = -2 * np.mean(X1 * (Y - Y_pred))
  dm2 = -2 * np.mean(X2 * (Y - Y_pred))
  dc = -2 * np.mean(Y - Y_pred)

  # updating the parameters
  m1 = m1 - LR * dm1
  m2 = m2 - LR * dm2
  c = c - LR * dc

# %% [markdown]
# # Plot a graph of the cost function as training progresses

# %%
  plt.plot(range(epochs), costs, 'ro')
  plt.title("Plot of cost function as training progresses")
  plt.show()

# %% [markdown]
# PRINTING THE FINAL VALUE FOR THE TRAINING

# %%
print("m1", m1)
print("m2", m2)
print("c", c)
