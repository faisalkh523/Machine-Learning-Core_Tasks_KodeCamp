# %% [markdown]
# <a href="https://colab.research.google.com/github/faisalkh523/Machine-Learning-Core_Tasks_KodeCamp/blob/main/Linear_Regression_with_one_variable_Task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Question 1: Linear Regression with Gradient Descent
#
# You have below loosely correlated values of X and Y in arrays. You are expected to write the code to carry out linear regression with gradient descent for the provided data. Ensure each step of the process is properly documented using a text block in your notebook just before the code block.
#
#
#
# Requirements:
#
# 1. Print out the MSE after each cycle of training.
# 2. Plot a graph of the cost function as training progresses.
# 3. Print out the final values of your model parameters, m and c.
# 4. Plot a scatter graph of the original X, Y values along with a line graph of the final linear model after training.

# %% [markdown]
# Importing libraries necessary for the Task

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
     2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
     5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
     7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

Y = np.array([ 2.60943416,  1.76213705,  7.18511292,  9.40744522,  5.46635068,
     8.6061673 , 13.30831239, 14.26225166, 16.70323979, 16.87285951,
    22.17984858, 23.81874177, 24.23732455, 28.20185083, 28.72449237,
    27.91299402, 32.21118578, 31.39802427, 36.91479534, 36.90014818])

# %% [markdown]
# # First step is to calculate the predicted **values**

# %%
def y_pred(X, m ,c):
    return m * X + c

# %% [markdown]
# # Second Step: Function for Computing the error

# %%
def compute_mse(y_true, y_pred):
  """Mean Squared Error"""
  return np.mean((y_true - y_pred)**2)

# %% [markdown]
# ## Function to compute the gradient

# %%
def gradients(x, y, m, c):
  n = x.shape[0]
  y_hat = m * x + c
  error = y - y_hat
  dm = (-2.0 / n) * np.sum(x * error)
  dc = (-2.0 / n) * np.sum(error)
  return dm, dc

# %% [markdown]
# # **Declaring Parameters**

# %%
LR = 0.01   # Learning rate
m = 0
c = 0
epochs = 50

ms = []
cs = []
errors = []

# %% [markdown]
# # Computing the gradient

# %%
for i in range(epochs):
  Y_hat = y_pred(X, m, c)
  error = compute_mse(Y, Y_hat)
  mse = errors.append(error)
  grad = gradients(X, Y, m, c)

  ms.append(m)
  cs.append(c)

  print(f"Epoch {i+1}: MSE = {error}")

 # Parameter adjustment
  m = m - LR * grad[0]
  c = c - LR * grad[1]
# Out:
# Epoch 1: MSE = 499.6111730062909
# Epoch 2: MSE = 48.0193235534004
# Epoch 3: MSE = 7.086096131836733
# Epoch 4: MSE = 3.373959700508118
# Epoch 5: MSE = 3.035471320605642
# Epoch 6: MSE = 3.002783292865769
# Epoch 7: MSE = 2.9978333594670312
# Epoch 8: MSE = 2.995418431614623
# Epoch 9: MSE = 2.99325394475838
# Epoch 10: MSE = 2.99113261430663
# Epoch 11: MSE = 2.989035437407186
# Epoch 12: MSE = 2.9869604788548996
# Epoch 13: MSE = 2.984907352651258
# Epoch 14: MSE = 2.982875815428266
# Epoch 15: MSE = 2.9808656389366446
# Epoch 16: MSE = 2.978876598465432
# Epoch 17: MSE = 2.976908471769563
# Epoch 18: MSE = 2.974961038950134
# Epoch 19: MSE = 2.9730340824212083
# Epoch 20: MSE = 2.9711273868847323
# Epoch 21: MSE = 2.969240739306423
# Epoch 22: MSE = 2.967373928891938
# Epoch 23: MSE = 2.9655267470633317
# Epoch 24: MSE = 2.963698987435757
# Epoch 25: MSE = 2.9618904457944053
# Epoch 26: MSE = 2.9601009200716786
# Epoch 27: MSE = 2.958330210324617
# Epoch 28: MSE = 2.95657811871257
# Epoch 29: MSE = 2.954844449475078
# Epoch 30: MSE = 2.9531290089100066
# Epoch 31: MSE = 2.9514316053519067
# Epoch 32: MSE = 2.9497520491505913
# Epoch 33: MSE = 2.948090152649951
# Epoch 34: MSE = 2.9464457301669924
# Epoch 35: MSE = 2.9448185979710786
# Epoch 36: MSE = 2.9432085742634246
# Epoch 37: MSE = 2.9416154791567495
# Epoch 38: MSE = 2.940039134655214
# Epoch 39: MSE = 2.9384793646345053
# Epoch 40: MSE = 2.9369359948221816
# Epoch 41: MSE = 2.9354088527781794
# Epoch 42: MSE = 2.9338977678755596
# Epoch 43: MSE = 2.9324025712814485
# Epoch 44: MSE = 2.9309230959381507
# Epoch 45: MSE = 2.929459176544522
# Epoch 46: MSE = 2.928010649537451
# Epoch 47: MSE = 2.9265773530736356
# Epoch 48: MSE = 2.925159127011459
# Epoch 49: MSE = 2.9237558128931234
# Epoch 50: MSE = 2.92236725392693

# %% [markdown]
# # Cost Function Graph as Training progress

# %%
plt.plot(X, Y, 'o')
for mi, ci in zip(ms, cs):
  plt.plot(X, mi * X + ci, '--')
plt.show()

# %% [markdown]
# # Final Value for model parameters m and c

# %%
print("The final value for m =", m)
print("The final value for c =", c)
# Out:
# The final value for m = 3.69852398037195
# The final value for c = 0.7588850167180425

# %% [markdown]
# #Scatter plot of the original X and Y. Along with final linear model after training

# %%
plt.figure(figsize=(8, 6))
plt.plot(X, Y, 'bo')
plt.plot(X, y_pred(X, m ,c), 'r--')
plt.show()
